# %%
from epilink import MolecularClock, TOIT, linkage_probability

import numpy as np

# %%
clock = MolecularClock()
toit = TOIT()

# %%
linkage_probability(toit, clock,0,0, intermediate_hosts=100)
# Out:
# 0.8362766689607708

# %%
np.log10(0.001)
# Out:
# np.float64(-3.0)

# %%
# Out:
# -11
