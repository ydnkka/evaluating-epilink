# %%
from epilink import MolecularClock

# %%
clock = MolecularClock()

# %%
clock.expected_mutations([10, 15], size=5)
# Out:
# array([[1.68344407, 2.5251661 ],
#        [1.06801366, 1.60202049],
#        [0.60386705, 0.90580058],
#        [1.04490083, 1.56735124],
#        [0.66504671, 0.99757007]])

# %%
clock.expected_mutations([10, 15], size=5)
# Out:
# array([[0.76046059, 1.14069088],
#        [1.00653645, 1.50980468],
#        [0.5124747 , 0.76871205],
#        [0.93822032, 1.40733049],
#        [1.23104034, 1.84656051]])
